# %%
import os
import csv

# Path to your CSV file
csv_file_path = '/content/drive/MyDrive/DermatoAI/SeturiDateFinaleClasificareBoliPiele/Dataset-agumentat-mediu-undersampling/metadata.csv'

# Directory where your images are stored
image_directory = '/content/drive/MyDrive/DermatoAI/SeturiDateFinaleClasificareBoliPiele/Dataset-agumentat-mediu-undersampling/dataset'

missing_files = []
i = 0
# Assuming your CSV has headers and 'isic_id' is the column with image filenames
with open(csv_file_path, mode='r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        isic_id = row['isic_id']  # Adjust the key if your column name is different
        image_path = os.path.join(image_directory, f"{isic_id}")  # Adjust extension if needed
        if not os.path.exists(image_path):
            missing_files.append(isic_id)

# Print the number of missing files and some examples
print(f"Total missing files: {len(missing_files)}")
if len(missing_files) > 0:
    print("Examples of missing files:", missing_files[:10])
# Out:
# Total missing files: 0

# %%
# !cp -r "/content/drive/MyDrive/DermatoAI/SetClasificareBoliBalanced" "/content/sample_data"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/drive/MyDrive/DermatoAI/SetClasificareBoliBalanced.zip" -d "/content/drive/MyDrive/DermatoAI"

# %%
import os

def count_files(directory):
    total_files = 0
    for root, dirs, files in os.walk(directory):
        total_files += len(files)
    return total_files
print(count_files('/content/sample_data/SetClasificareBoliBalanced'))
# Out:
# 12000

# %%
import pandas as pd
import tensorflow as tf
from keras.src.layers import Flatten
from sklearn.utils import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import numpy as np
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications import InceptionResNetV2



np.random.seed(42)
target_size = (450, 600)
batch = 16
epoci = 20

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()


image_directory = '/content/sample_data/SetClasificareBoliBalanced'


datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)  # 30% of data for validation

# Create the training generator
train_generator = datagen.flow_from_directory(
    directory=image_directory,  # Make sure this is the path to the image directory
    target_size=target_size,
    shuffle=True,
    batch_size=batch,
    class_mode='categorical',  # Using 'categorical' since you have more than 2 classes
    subset='training',  # Set subset to training
    seed=42
)

# Create the validation generator
validation_generator = datagen.flow_from_directory(
    directory=image_directory,  # Make sure this is the path to the image directory
    target_size=target_size,
    shuffle=False,
    batch_size=batch,
    class_mode='categorical',  # Using 'categorical' since you have more than 2 classes
    subset='validation',  # Set subset to validation
    seed=42
)

class_indices = train_generator.class_indices

# Print the class indices
print("Class Indices:", class_indices)

# Invert the dictionary to map indices to class names
index_to_class = {v: k for k, v in class_indices.items()}
print("Index to Class:", index_to_class)


base_model = InceptionResNetV2(include_top=False, weights='imagenet', input_shape=(target_size[0], target_size[1], 3))
for layer in base_model.layers[:-30]:  # This is just an example; adjust the number as needed
    layer.trainable = False
# Freeze the convolutional base
#base_model.trainable = False

# Build the model
x = base_model.output
x = GlobalAveragePooling2D()(x)

# Adjust the number of units and dropout rate as needed
x = Dense(512, activation='relu')(x)  # Increased units as InceptionResNetV2 is more complex
x = Dropout(0.7)(x)  # Increased dropout to prevent overfitting

x = Dense(256, activation='relu')(x)  # Increased units as InceptionResNetV2 is more complex
x = Dropout(0.5)(x)  # Increased dropout to prevent overfitting


predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=predictions)

model.compile(optimizer=Adam(learning_rate=0.0004),
              loss=CategoricalCrossentropy(),
              metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), F1Score()])

model.summary()


callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, min_lr=1e-6),
    EarlyStopping(monitor='val_loss',min_delta=0.001, mode='min', patience=4, verbose=1, restore_best_weights=True)
]

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    # class_weight=class_weights,
    epochs=epoci,
    callbacks=callbacks
)

validation_generator.reset()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Predict on the whole validation set
predictions = model.predict(validation_generator, steps=np.ceil(validation_generator.n / validation_generator.batch_size))

# Get the class indices from the predictions
predicted_classes = np.argmax(predictions, axis=1)

# Retrieve the true class indices assigned by the generator
true_classes = validation_generator.classes

# Match the order of the class indices
class_labels = list(validation_generator.class_indices.keys())

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Visualize the confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Generate a classification report
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Save the model
model.save('/content/drive/MyDrive/DermatoAI/Models/balanced_MobileNet_2.h5')
# Out:
# Found 8400 images belonging to 8 classes.
# Found 3600 images belonging to 8 classes.
# Class Indices: {'actinic_keratosis': 0, 'basal_cell_carcinoma': 1, 'dermatofibroma': 2, 'melanoma': 3, 'nevus': 4, 'pigmented_benign_keratosis': 5, 'squamous_cell_carcinoma': 6, 'vascular_lesion': 7}
# Index to Class: {0: 'actinic_keratosis', 1: 'basal_cell_carcinoma', 2: 'dermatofibroma', 3: 'melanoma', 4: 'nevus', 5: 'pigmented_benign_keratosis', 6: 'squamous_cell_carcinoma', 7: 'vascular_lesion'}
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 450, 600, 3)]        0         []
#
#  conv2d_1218 (Conv2D)        (None, 224, 299, 32)         864       ['input_15[0][0]']
#
#  batch_normalization_1218 (  (None, 224, 299, 32)         96        ['conv2d_1218[0][0]']
#  BatchNormalization)
#
#  activation_1218 (Activatio  (None, 224, 299, 32)         0         ['batch_normalization_1218[0][
#  n)                                                                 0]']
#
#  conv2d_1219 (Conv2D)        (None, 222, 297, 32)         9216      ['activation_1218[0][0]']
#
#  batch_normalization_1219 (  (None, 222, 297, 32)         96        ['conv2d_1219[0][0]']
#  BatchNormalization)
#
#  activation_1219 (Activatio  (None, 222, 297, 32)         0         ['batch_normalization_1219[0][
#  n)                                                                 0]']
#
#  conv2d_1220 (Conv2D)        (None, 222, 297, 64)         18432     ['activation_1219[0][0]']
#
#  batch_normalization_1220 (  (None, 222, 297, 64)         192       ['conv2d_1220[0][0]']
#  BatchNormalization)
#
#  activation_1220 (Activatio  (None, 222, 297, 64)         0         ['batch_normalization_1220[0][
#  n)                                                                 0]']
#
#  max_pooling2d_24 (MaxPooli  (None, 110, 148, 64)         0         ['activation_1220[0][0]']
#  ng2D)
#
#  conv2d_1221 (Conv2D)        (None, 110, 148, 80)         5120      ['max_pooling2d_24[0][0]']
#
#  batch_normalization_1221 (  (None, 110, 148, 80)         240       ['conv2d_1221[0][0]']
#  BatchNormalization)
#
#  activation_1221 (Activatio  (None, 110, 148, 80)         0         ['batch_normalization_1221[0][
#  n)                                                                 0]']
#
#  conv2d_1222 (Conv2D)        (None, 108, 146, 192)        138240    ['activation_1221[0][0]']
#
#  batch_normalization_1222 (  (None, 108, 146, 192)        576       ['conv2d_1222[0][0]']
#  BatchNormalization)
#
#  activation_1222 (Activatio  (None, 108, 146, 192)        0         ['batch_normalization_1222[0][
#  n)                                                                 0]']
#
#  max_pooling2d_25 (MaxPooli  (None, 53, 72, 192)          0         ['activation_1222[0][0]']
#  ng2D)
#
#  conv2d_1226 (Conv2D)        (None, 53, 72, 64)           12288     ['max_pooling2d_25[0][0]']
#
#  batch_normalization_1226 (  (None, 53, 72, 64)           192       ['conv2d_1226[0][0]']
#  BatchNormalization)
#
#  activation_1226 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1226[0][
#  n)                                                                 0]']
#
#  conv2d_1224 (Conv2D)        (None, 53, 72, 48)           9216      ['max_pooling2d_25[0][0]']
#
#  conv2d_1227 (Conv2D)        (None, 53, 72, 96)           55296     ['activation_1226[0][0]']
#
#  batch_normalization_1224 (  (None, 53, 72, 48)           144       ['conv2d_1224[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1227 (  (None, 53, 72, 96)           288       ['conv2d_1227[0][0]']
#  BatchNormalization)
#
#  activation_1224 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1224[0][
#  n)                                                                 0]']
#
#  activation_1227 (Activatio  (None, 53, 72, 96)           0         ['batch_normalization_1227[0][
#  n)                                                                 0]']
#
#  average_pooling2d_6 (Avera  (None, 53, 72, 192)          0         ['max_pooling2d_25[0][0]']
#  gePooling2D)
#
#  conv2d_1223 (Conv2D)        (None, 53, 72, 96)           18432     ['max_pooling2d_25[0][0]']
#
#  conv2d_1225 (Conv2D)        (None, 53, 72, 64)           76800     ['activation_1224[0][0]']
#
#  conv2d_1228 (Conv2D)        (None, 53, 72, 96)           82944     ['activation_1227[0][0]']
#
#  conv2d_1229 (Conv2D)        (None, 53, 72, 64)           12288     ['average_pooling2d_6[0][0]']
#
#  batch_normalization_1223 (  (None, 53, 72, 96)           288       ['conv2d_1223[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1225 (  (None, 53, 72, 64)           192       ['conv2d_1225[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1228 (  (None, 53, 72, 96)           288       ['conv2d_1228[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1229 (  (None, 53, 72, 64)           192       ['conv2d_1229[0][0]']
#  BatchNormalization)
#
#  activation_1223 (Activatio  (None, 53, 72, 96)           0         ['batch_normalization_1223[0][
#  n)                                                                 0]']
#
#  activation_1225 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1225[0][
#  n)                                                                 0]']
#
#  activation_1228 (Activatio  (None, 53, 72, 96)           0         ['batch_normalization_1228[0][
#  n)                                                                 0]']
#
#  activation_1229 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1229[0][
#  n)                                                                 0]']
#
#  mixed_5b (Concatenate)      (None, 53, 72, 320)          0         ['activation_1223[0][0]',
#                                                                      'activation_1225[0][0]',
#                                                                      'activation_1228[0][0]',
#                                                                      'activation_1229[0][0]']
#
#  conv2d_1233 (Conv2D)        (None, 53, 72, 32)           10240     ['mixed_5b[0][0]']
#
#  batch_normalization_1233 (  (None, 53, 72, 32)           96        ['conv2d_1233[0][0]']
#  BatchNormalization)
#
#  activation_1233 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1233[0][
#  n)                                                                 0]']
#
#  conv2d_1231 (Conv2D)        (None, 53, 72, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_1234 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1233[0][0]']
#
#  batch_normalization_1231 (  (None, 53, 72, 32)           96        ['conv2d_1231[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1234 (  (None, 53, 72, 48)           144       ['conv2d_1234[0][0]']
#  BatchNormalization)
#
#  activation_1231 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1231[0][
#  n)                                                                 0]']
#
#  activation_1234 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1234[0][
#  n)                                                                 0]']
#
#  conv2d_1230 (Conv2D)        (None, 53, 72, 32)           10240     ['mixed_5b[0][0]']
#
#  conv2d_1232 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1231[0][0]']
#
#  conv2d_1235 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1234[0][0]']
#
#  batch_normalization_1230 (  (None, 53, 72, 32)           96        ['conv2d_1230[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1232 (  (None, 53, 72, 32)           96        ['conv2d_1232[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1235 (  (None, 53, 72, 64)           192       ['conv2d_1235[0][0]']
#  BatchNormalization)
#
#  activation_1230 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1230[0][
#  n)                                                                 0]']
#
#  activation_1232 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1232[0][
#  n)                                                                 0]']
#
#  activation_1235 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1235[0][
#  n)                                                                 0]']
#
#  block35_1_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1230[0][0]',
#  te)                                                                 'activation_1232[0][0]',
#                                                                      'activation_1235[0][0]']
#
#  block35_1_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_1_mixed[0][0]']
#
#  custom_scale_layer_240 (Cu  (None, 53, 72, 320)          0         ['mixed_5b[0][0]',
#  stomScaleLayer)                                                     'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_240[0][0]
#                                                                     ']
#
#  conv2d_1239 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_1_ac[0][0]']
#
#  batch_normalization_1239 (  (None, 53, 72, 32)           96        ['conv2d_1239[0][0]']
#  BatchNormalization)
#
#  activation_1239 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1239[0][
#  n)                                                                 0]']
#
#  conv2d_1237 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_1240 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1239[0][0]']
#
#  batch_normalization_1237 (  (None, 53, 72, 32)           96        ['conv2d_1237[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1240 (  (None, 53, 72, 48)           144       ['conv2d_1240[0][0]']
#  BatchNormalization)
#
#  activation_1237 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1237[0][
#  n)                                                                 0]']
#
#  activation_1240 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1240[0][
#  n)                                                                 0]']
#
#  conv2d_1236 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_1_ac[0][0]']
#
#  conv2d_1238 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1237[0][0]']
#
#  conv2d_1241 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1240[0][0]']
#
#  batch_normalization_1236 (  (None, 53, 72, 32)           96        ['conv2d_1236[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1238 (  (None, 53, 72, 32)           96        ['conv2d_1238[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1241 (  (None, 53, 72, 64)           192       ['conv2d_1241[0][0]']
#  BatchNormalization)
#
#  activation_1236 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1236[0][
#  n)                                                                 0]']
#
#  activation_1238 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1238[0][
#  n)                                                                 0]']
#
#  activation_1241 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1241[0][
#  n)                                                                 0]']
#
#  block35_2_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1236[0][0]',
#  te)                                                                 'activation_1238[0][0]',
#                                                                      'activation_1241[0][0]']
#
#  block35_2_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_2_mixed[0][0]']
#
#  custom_scale_layer_241 (Cu  (None, 53, 72, 320)          0         ['block35_1_ac[0][0]',
#  stomScaleLayer)                                                     'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_241[0][0]
#                                                                     ']
#
#  conv2d_1245 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_2_ac[0][0]']
#
#  batch_normalization_1245 (  (None, 53, 72, 32)           96        ['conv2d_1245[0][0]']
#  BatchNormalization)
#
#  activation_1245 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1245[0][
#  n)                                                                 0]']
#
#  conv2d_1243 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_1246 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1245[0][0]']
#
#  batch_normalization_1243 (  (None, 53, 72, 32)           96        ['conv2d_1243[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1246 (  (None, 53, 72, 48)           144       ['conv2d_1246[0][0]']
#  BatchNormalization)
#
#  activation_1243 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1243[0][
#  n)                                                                 0]']
#
#  activation_1246 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1246[0][
#  n)                                                                 0]']
#
#  conv2d_1242 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_2_ac[0][0]']
#
#  conv2d_1244 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1243[0][0]']
#
#  conv2d_1247 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1246[0][0]']
#
#  batch_normalization_1242 (  (None, 53, 72, 32)           96        ['conv2d_1242[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1244 (  (None, 53, 72, 32)           96        ['conv2d_1244[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1247 (  (None, 53, 72, 64)           192       ['conv2d_1247[0][0]']
#  BatchNormalization)
#
#  activation_1242 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1242[0][
#  n)                                                                 0]']
#
#  activation_1244 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1244[0][
#  n)                                                                 0]']
#
#  activation_1247 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1247[0][
#  n)                                                                 0]']
#
#  block35_3_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1242[0][0]',
#  te)                                                                 'activation_1244[0][0]',
#                                                                      'activation_1247[0][0]']
#
#  block35_3_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_3_mixed[0][0]']
#
#  custom_scale_layer_242 (Cu  (None, 53, 72, 320)          0         ['block35_2_ac[0][0]',
#  stomScaleLayer)                                                     'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_242[0][0]
#                                                                     ']
#
#  conv2d_1251 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_3_ac[0][0]']
#
#  batch_normalization_1251 (  (None, 53, 72, 32)           96        ['conv2d_1251[0][0]']
#  BatchNormalization)
#
#  activation_1251 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1251[0][
#  n)                                                                 0]']
#
#  conv2d_1249 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_1252 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1251[0][0]']
#
#  batch_normalization_1249 (  (None, 53, 72, 32)           96        ['conv2d_1249[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1252 (  (None, 53, 72, 48)           144       ['conv2d_1252[0][0]']
#  BatchNormalization)
#
#  activation_1249 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1249[0][
#  n)                                                                 0]']
#
#  activation_1252 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1252[0][
#  n)                                                                 0]']
#
#  conv2d_1248 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_3_ac[0][0]']
#
#  conv2d_1250 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1249[0][0]']
#
#  conv2d_1253 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1252[0][0]']
#
#  batch_normalization_1248 (  (None, 53, 72, 32)           96        ['conv2d_1248[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1250 (  (None, 53, 72, 32)           96        ['conv2d_1250[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1253 (  (None, 53, 72, 64)           192       ['conv2d_1253[0][0]']
#  BatchNormalization)
#
#  activation_1248 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1248[0][
#  n)                                                                 0]']
#
#  activation_1250 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1250[0][
#  n)                                                                 0]']
#
#  activation_1253 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1253[0][
#  n)                                                                 0]']
#
#  block35_4_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1248[0][0]',
#  te)                                                                 'activation_1250[0][0]',
#                                                                      'activation_1253[0][0]']
#
#  block35_4_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_4_mixed[0][0]']
#
#  custom_scale_layer_243 (Cu  (None, 53, 72, 320)          0         ['block35_3_ac[0][0]',
#  stomScaleLayer)                                                     'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_243[0][0]
#                                                                     ']
#
#  conv2d_1257 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_4_ac[0][0]']
#
#  batch_normalization_1257 (  (None, 53, 72, 32)           96        ['conv2d_1257[0][0]']
#  BatchNormalization)
#
#  activation_1257 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1257[0][
#  n)                                                                 0]']
#
#  conv2d_1255 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_1258 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1257[0][0]']
#
#  batch_normalization_1255 (  (None, 53, 72, 32)           96        ['conv2d_1255[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1258 (  (None, 53, 72, 48)           144       ['conv2d_1258[0][0]']
#  BatchNormalization)
#
#  activation_1255 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1255[0][
#  n)                                                                 0]']
#
#  activation_1258 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1258[0][
#  n)                                                                 0]']
#
#  conv2d_1254 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_4_ac[0][0]']
#
#  conv2d_1256 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1255[0][0]']
#
#  conv2d_1259 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1258[0][0]']
#
#  batch_normalization_1254 (  (None, 53, 72, 32)           96        ['conv2d_1254[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1256 (  (None, 53, 72, 32)           96        ['conv2d_1256[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1259 (  (None, 53, 72, 64)           192       ['conv2d_1259[0][0]']
#  BatchNormalization)
#
#  activation_1254 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1254[0][
#  n)                                                                 0]']
#
#  activation_1256 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1256[0][
#  n)                                                                 0]']
#
#  activation_1259 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1259[0][
#  n)                                                                 0]']
#
#  block35_5_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1254[0][0]',
#  te)                                                                 'activation_1256[0][0]',
#                                                                      'activation_1259[0][0]']
#
#  block35_5_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_5_mixed[0][0]']
#
#  custom_scale_layer_244 (Cu  (None, 53, 72, 320)          0         ['block35_4_ac[0][0]',
#  stomScaleLayer)                                                     'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_244[0][0]
#                                                                     ']
#
#  conv2d_1263 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_5_ac[0][0]']
#
#  batch_normalization_1263 (  (None, 53, 72, 32)           96        ['conv2d_1263[0][0]']
#  BatchNormalization)
#
#  activation_1263 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1263[0][
#  n)                                                                 0]']
#
#  conv2d_1261 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_1264 (Conv2D)        (None, 53, 72, 48)           13824     ['activation_1263[0][0]']
#
#  batch_normalization_1261 (  (None, 53, 72, 32)           96        ['conv2d_1261[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1264 (  (None, 53, 72, 48)           144       ['conv2d_1264[0][0]']
#  BatchNormalization)
#
#  activation_1261 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1261[0][
#  n)                                                                 0]']
#
#  activation_1264 (Activatio  (None, 53, 72, 48)           0         ['batch_normalization_1264[0][
#  n)                                                                 0]']
#
#  conv2d_1260 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_5_ac[0][0]']
#
#  conv2d_1262 (Conv2D)        (None, 53, 72, 32)           9216      ['activation_1261[0][0]']
#
#  conv2d_1265 (Conv2D)        (None, 53, 72, 64)           27648     ['activation_1264[0][0]']
#
#  batch_normalization_1260 (  (None, 53, 72, 32)           96        ['conv2d_1260[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1262 (  (None, 53, 72, 32)           96        ['conv2d_1262[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1265 (  (None, 53, 72, 64)           192       ['conv2d_1265[0][0]']
#  BatchNormalization)
#
#  activation_1260 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1260[0][
#  n)                                                                 0]']
#
#  activation_1262 (Activatio  (None, 53, 72, 32)           0         ['batch_normalization_1262[0][
#  n)                                                                 0]']
#
#  activation_1265 (Activatio  (None, 53, 72, 64)           0         ['batch_normalization_1265[0][
#  n)                                                                 0]']
#
#  block35_6_mixed (Concatena  (None, 53, 72, 128)          0         ['activation_1260[0][0]',
#  te)                                                                 'activation_1262[0][0]',
#                                                                      'activation_1265[0][0]']
#
#  block35_6_conv (Conv2D)     (None, 53, 72, 320)          41280     ['block35_6_mixed[0][0]']
#
#  custom_scale_layer_245 (Cu  (None, 53, 72, 320)          0         ['block35_5_ac[0][0]',
#  stomScaleLayer)                                                     'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)   (None, 53, 72, 320)          0         ['custom_scale_layer_245[0][0]
#                                                                     ']
#
#  conv2d_1269 (Conv2D)        (None, 53, 72, 32)           10240     ['block35_6_ac[0][0]']
#
#  batch_normalization_1269 (  (None, 53, 72, 32)           96        ['conv2d_1269[0][0]']
#  BatchNormalization)
# ...
#
#  block8_8_ac (Activation)    (None, 12, 17, 2080)         0         ['custom_scale_layer_277[0][0]
#                                                                     ']
#
#  conv2d_1414 (Conv2D)        (None, 12, 17, 192)          399360    ['block8_8_ac[0][0]']
#
#  batch_normalization_1414 (  (None, 12, 17, 192)          576       ['conv2d_1414[0][0]']
#  BatchNormalization)
#
#  activation_1414 (Activatio  (None, 12, 17, 192)          0         ['batch_normalization_1414[0][
#  n)                                                                 0]']
#
#  conv2d_1415 (Conv2D)        (None, 12, 17, 224)          129024    ['activation_1414[0][0]']
#
#  batch_normalization_1415 (  (None, 12, 17, 224)          672       ['conv2d_1415[0][0]']
#  BatchNormalization)
#
#  activation_1415 (Activatio  (None, 12, 17, 224)          0         ['batch_normalization_1415[0][
#  n)                                                                 0]']
#
#  conv2d_1413 (Conv2D)        (None, 12, 17, 192)          399360    ['block8_8_ac[0][0]']
#
#  conv2d_1416 (Conv2D)        (None, 12, 17, 256)          172032    ['activation_1415[0][0]']
#
#  batch_normalization_1413 (  (None, 12, 17, 192)          576       ['conv2d_1413[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1416 (  (None, 12, 17, 256)          768       ['conv2d_1416[0][0]']
#  BatchNormalization)
#
#  activation_1413 (Activatio  (None, 12, 17, 192)          0         ['batch_normalization_1413[0][
#  n)                                                                 0]']
#
#  activation_1416 (Activatio  (None, 12, 17, 256)          0         ['batch_normalization_1416[0][
#  n)                                                                 0]']
#
#  block8_9_mixed (Concatenat  (None, 12, 17, 448)          0         ['activation_1413[0][0]',
#  e)                                                                  'activation_1416[0][0]']
#
#  block8_9_conv (Conv2D)      (None, 12, 17, 2080)         933920    ['block8_9_mixed[0][0]']
#
#  custom_scale_layer_278 (Cu  (None, 12, 17, 2080)         0         ['block8_8_ac[0][0]',
#  stomScaleLayer)                                                     'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)    (None, 12, 17, 2080)         0         ['custom_scale_layer_278[0][0]
#                                                                     ']
#
#  conv2d_1418 (Conv2D)        (None, 12, 17, 192)          399360    ['block8_9_ac[0][0]']
#
#  batch_normalization_1418 (  (None, 12, 17, 192)          576       ['conv2d_1418[0][0]']
#  BatchNormalization)
#
#  activation_1418 (Activatio  (None, 12, 17, 192)          0         ['batch_normalization_1418[0][
#  n)                                                                 0]']
#
#  conv2d_1419 (Conv2D)        (None, 12, 17, 224)          129024    ['activation_1418[0][0]']
#
#  batch_normalization_1419 (  (None, 12, 17, 224)          672       ['conv2d_1419[0][0]']
#  BatchNormalization)
#
#  activation_1419 (Activatio  (None, 12, 17, 224)          0         ['batch_normalization_1419[0][
#  n)                                                                 0]']
#
#  conv2d_1417 (Conv2D)        (None, 12, 17, 192)          399360    ['block8_9_ac[0][0]']
#
#  conv2d_1420 (Conv2D)        (None, 12, 17, 256)          172032    ['activation_1419[0][0]']
#
#  batch_normalization_1417 (  (None, 12, 17, 192)          576       ['conv2d_1417[0][0]']
#  BatchNormalization)
#
#  batch_normalization_1420 (  (None, 12, 17, 256)          768       ['conv2d_1420[0][0]']
#  BatchNormalization)
#
#  activation_1417 (Activatio  (None, 12, 17, 192)          0         ['batch_normalization_1417[0][
#  n)                                                                 0]']
#
#  activation_1420 (Activatio  (None, 12, 17, 256)          0         ['batch_normalization_1420[0][
#  n)                                                                 0]']
#
#  block8_10_mixed (Concatena  (None, 12, 17, 448)          0         ['activation_1417[0][0]',
#  te)                                                                 'activation_1420[0][0]']
#
#  block8_10_conv (Conv2D)     (None, 12, 17, 2080)         933920    ['block8_10_mixed[0][0]']
#
#  custom_scale_layer_279 (Cu  (None, 12, 17, 2080)         0         ['block8_9_ac[0][0]',
#  stomScaleLayer)                                                     'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)            (None, 12, 17, 1536)         3194880   ['custom_scale_layer_279[0][0]
#                                                                     ']
#
#  conv_7b_bn (BatchNormaliza  (None, 12, 17, 1536)         4608      ['conv_7b[0][0]']
#  tion)
#
#  conv_7b_ac (Activation)     (None, 12, 17, 1536)         0         ['conv_7b_bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1536)                 0         ['conv_7b_ac[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  dense_39 (Dense)            (None, 512)                  786944    ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  dropout_25 (Dropout)        (None, 512)                  0         ['dense_39[0][0]']
#
#  dense_40 (Dense)            (None, 256)                  131328    ['dropout_25[0][0]']
#
#  dropout_26 (Dropout)        (None, 256)                  0         ['dense_40[0][0]']
#
#  dense_41 (Dense)            (None, 8)                    2056      ['dropout_26[0][0]']
#
# ==================================================================================================
# Total params: 55257064 (210.79 MB)
# Trainable params: 7657288 (29.21 MB)
# Non-trainable params: 47599776 (181.58 MB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 525/525 [==============================] - 97s 160ms/step - loss: 1.5211 - accuracy: 0.4356 - precision_26: 0.6821 - recall_26: 0.2276 - f1_score: 0.3413 - val_loss: 1.3516 - val_accuracy: 0.5736 - val_precision_26: 0.7263 - val_recall_26: 0.4194 - val_f1_score: 0.5318 - lr: 4.0000e-04
# Epoch 2/20
# 525/525 [==============================] - 77s 147ms/step - loss: 1.0063 - accuracy: 0.6446 - precision_26: 0.7709 - recall_26: 0.4939 - f1_score: 0.6021 - val_loss: 0.9069 - val_accuracy: 0.6961 - val_precision_26: 0.8338 - val_recall_26: 0.5394 - val_f1_score: 0.6551 - lr: 4.0000e-04
# Epoch 3/20
# 525/525 [==============================] - 80s 152ms/step - loss: 0.7910 - accuracy: 0.7245 - precision_26: 0.8199 - recall_26: 0.6151 - f1_score: 0.7029 - val_loss: 0.9999 - val_accuracy: 0.6758 - val_precision_26: 0.7730 - val_recall_26: 0.5856 - val_f1_score: 0.6664 - lr: 4.0000e-04
# Epoch 4/20
# 525/525 [==============================] - 80s 152ms/step - loss: 0.6113 - accuracy: 0.7894 - precision_26: 0.8580 - recall_26: 0.7115 - f1_score: 0.7780 - val_loss: 1.1857 - val_accuracy: 0.6272 - val_precision_26: 0.7762 - val_recall_26: 0.5319 - val_f1_score: 0.6313 - lr: 4.0000e-04
# Epoch 5/20
# 525/525 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.8298 - precision_26: 0.8800 - recall_26: 0.7677 - f1_score: 0.8201
# Epoch 5: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# 525/525 [==============================] - 80s 152ms/step - loss: 0.4994 - accuracy: 0.8298 - precision_26: 0.8800 - recall_26: 0.7677 - f1_score: 0.8201 - val_loss: 1.0681 - val_accuracy: 0.6769 - val_precision_26: 0.7706 - val_recall_26: 0.6083 - val_f1_score: 0.6799 - lr: 4.0000e-04
# Epoch 6/20
# 525/525 [==============================] - 81s 153ms/step - loss: 0.3182 - accuracy: 0.8946 - precision_26: 0.9254 - recall_26: 0.8504 - f1_score: 0.8863 - val_loss: 0.8495 - val_accuracy: 0.7458 - val_precision_26: 0.8080 - val_recall_26: 0.6981 - val_f1_score: 0.7490 - lr: 4.0000e-05
# Epoch 7/20
# 525/525 [==============================] - 80s 152ms/step - loss: 0.2452 - accuracy: 0.9229 - precision_26: 0.9428 - recall_26: 0.8944 - f1_score: 0.9180 - val_loss: 0.9163 - val_accuracy: 0.7447 - val_precision_26: 0.7973 - val_recall_26: 0.7122 - val_f1_score: 0.7523 - lr: 4.0000e-05
# Epoch 8/20
# 525/525 [==============================] - 81s 153ms/step - loss: 0.2144 - accuracy: 0.9267 - precision_26: 0.9449 - recall_26: 0.9061 - f1_score: 0.9251 - val_loss: 0.9048 - val_accuracy: 0.7517 - val_precision_26: 0.7966 - val_recall_26: 0.7181 - val_f1_score: 0.7553 - lr: 4.0000e-05
# Epoch 9/20
# 525/525 [==============================] - ETA: 0s - loss: 0.1852 - accuracy: 0.9381 - precision_26: 0.9527 - recall_26: 0.9213 - f1_score: 0.9368
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 525/525 [==============================] - 82s 156ms/step - loss: 0.1852 - accuracy: 0.9381 - precision_26: 0.9527 - recall_26: 0.9213 - f1_score: 0.9368 - val_loss: 0.8625 - val_accuracy: 0.7661 - val_precision_26: 0.8000 - val_recall_26: 0.7378 - val_f1_score: 0.7676 - lr: 4.0000e-05
# Epoch 10/20
# 525/525 [==============================] - ETA: 0s - loss: 0.1648 - accuracy: 0.9473 - precision_26: 0.9597 - recall_26: 0.9320 - f1_score: 0.9456Restoring model weights from the end of the best epoch: 6.
# 525/525 [==============================] - 81s 155ms/step - loss: 0.1648 - accuracy: 0.9473 - precision_26: 0.9597 - recall_26: 0.9320 - f1_score: 0.9456 - val_loss: 0.9018 - val_accuracy: 0.7600 - val_precision_26: 0.7938 - val_recall_26: 0.7325 - val_f1_score: 0.7619 - lr: 4.0000e-06
# Epoch 10: early stopping
# 225/225 [==============================] - 27s 108ms/step
#                             precision    recall  f1-score   support
#
#          actinic_keratosis       0.86      0.79      0.83       450
#       basal_cell_carcinoma       0.71      0.75      0.73       450
#             dermatofibroma       0.94      0.74      0.83       450
#                   melanoma       0.59      0.57      0.58       450
#                      nevus       0.74      0.82      0.78       450
# pigmented_benign_keratosis       0.53      0.79      0.63       450
#    squamous_cell_carcinoma       0.84      0.64      0.73       450
#            vascular_lesion       0.93      0.86      0.89       450
#
#                   accuracy                           0.75      3600
#                  macro avg       0.77      0.75      0.75      3600
#               weighted avg       0.77      0.75      0.75      3600
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from google.colab import files
files.download('/content/drive/MyDrive/DermatoAI/mediu_undersampling_model1.h5')
