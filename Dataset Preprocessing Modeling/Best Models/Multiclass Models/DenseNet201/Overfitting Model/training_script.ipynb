# %%
import os
import csv

# Path to your CSV file
csv_file_path = '/content/drive/MyDrive/DermatoAI/SeturiDateFinaleClasificareBoliPiele/Dataset-agumentat-mediu-undersampling/metadata.csv'

# Directory where your images are stored
image_directory = '/content/drive/MyDrive/DermatoAI/SeturiDateFinaleClasificareBoliPiele/Dataset-agumentat-mediu-undersampling/dataset'

missing_files = []
i = 0
# Assuming your CSV has headers and 'isic_id' is the column with image filenames
with open(csv_file_path, mode='r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        isic_id = row['isic_id']  # Adjust the key if your column name is different
        image_path = os.path.join(image_directory, f"{isic_id}")  # Adjust extension if needed
        if not os.path.exists(image_path):
            missing_files.append(isic_id)

# Print the number of missing files and some examples
print(f"Total missing files: {len(missing_files)}")
if len(missing_files) > 0:
    print("Examples of missing files:", missing_files[:10])
# Out:
# Total missing files: 0

# %%
# !cp -r "/content/drive/MyDrive/DermatoAI/SetClasificareBoliBalanced" "/content/sample_data"

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !unzip "/content/drive/MyDrive/DermatoAI/SetClasificareBoliBalanced.zip" -d "/content/drive/MyDrive/DermatoAI"

# %%
import os

def count_files(directory):
    total_files = 0
    for root, dirs, files in os.walk(directory):
        total_files += len(files)
    return total_files
print(count_files('/content/sample_data/SetClasificareBoliBalanced'))
# Out:
# 12000

# %%
import pandas as pd
import tensorflow as tf
from keras.src.layers import Flatten
from sklearn.utils import compute_class_weight
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from keras import backend as K
import numpy as np
from tensorflow.keras.layers import GlobalAveragePooling2D, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import DenseNet169
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.applications import MobileNetV3Small
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.regularizers import l2
from tensorflow.keras.applications import VGG19





np.random.seed(42)
target_size = (450, 600)
batch = 16
epoci = 20

class F1Score(tf.keras.metrics.Metric):
    def __init__(self, name='f1_score', **kwargs):
        super(F1Score, self).__init__(name=name, **kwargs)
        self.precision = tf.keras.metrics.Precision()
        self.recall = tf.keras.metrics.Recall()

    def update_state(self, y_true, y_pred, sample_weight=None):
        self.precision.update_state(y_true, y_pred, sample_weight)
        self.recall.update_state(y_true, y_pred, sample_weight)

    def result(self):
        p = self.precision.result()
        r = self.recall.result()
        return 2 * ((p * r) / (p + r + K.epsilon()))

    def reset_states(self):
        self.precision.reset_states()
        self.recall.reset_states()


image_directory = '/content/sample_data/SetClasificareBoliBalanced'


datagen = ImageDataGenerator(rescale=1./255, validation_split=0.3)  # 30% of data for validation

# Create the training generator
train_generator = datagen.flow_from_directory(
    directory=image_directory,  # Make sure this is the path to the image directory
    target_size=target_size,
    shuffle=True,
    batch_size=batch,
    class_mode='categorical',  # Using 'categorical' since you have more than 2 classes
    subset='training',  # Set subset to training
    seed=42
)

# Create the validation generator
validation_generator = datagen.flow_from_directory(
    directory=image_directory,  # Make sure this is the path to the image directory
    target_size=target_size,
    shuffle=False,
    batch_size=batch,
    class_mode='categorical',  # Using 'categorical' since you have more than 2 classes
    subset='validation',  # Set subset to validation
    seed=42
)

class_indices = train_generator.class_indices

# Print the class indices
print("Class Indices:", class_indices)

# Invert the dictionary to map indices to class names
index_to_class = {v: k for k, v in class_indices.items()}
print("Index to Class:", index_to_class)

base_model = DenseNet201(include_top=False, weights='imagenet', input_shape=(target_size[0], target_size[1], 3))

for layer in base_model.layers[:-40]:
    layer.trainable = False
#base_model.trainable = False

# Custom top layers for our specific task
x = base_model.output
x = GlobalAveragePooling2D()(x)

# First Dense block
x = Dense(512)(x)  # Increase the units
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.6)(x)  # Maintain dropout at 0.5

# Second Dense block (newly added)
x = Dense(256)(x)  # Add an extra Dense layer
x = BatchNormalization()(x)
x = Activation('relu')(x)
x = Dropout(0.6)(x)  # Slightly reduce dropout for this layer

# Output layer
predictions = Dense(len(train_generator.class_indices), activation='softmax')(x)

# Connecting the base model with the custom top layers
model = Model(inputs=base_model.input, outputs=predictions)

model.compile(
    loss=CategoricalCrossentropy(),
    optimizer=Adam(learning_rate=0.0003),
    metrics=['accuracy', tf.keras.metrics.Precision(), tf.keras.metrics.Recall(), F1Score()]
)

model.summary()


callbacks = [
    ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=3, verbose=1, min_lr=1e-6),
    EarlyStopping(monitor='val_loss',min_delta=0.001, mode='min', patience=4, verbose=1, restore_best_weights=True)
]

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.n // train_generator.batch_size,
    validation_data=validation_generator,
    validation_steps=validation_generator.n // validation_generator.batch_size,
    # class_weight=class_weights,
    epochs=epoci,
    callbacks=callbacks
)

validation_generator.reset()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Predict on the whole validation set
predictions = model.predict(validation_generator, steps=np.ceil(validation_generator.n / validation_generator.batch_size))

# Get the class indices from the predictions
predicted_classes = np.argmax(predictions, axis=1)

# Retrieve the true class indices assigned by the generator
true_classes = validation_generator.classes

# Match the order of the class indices
class_labels = list(validation_generator.class_indices.keys())

# Generate the confusion matrix
conf_matrix = confusion_matrix(true_classes, predicted_classes)

# Visualize the confusion matrix
plt.figure(figsize=(10, 10))
sns.heatmap(conf_matrix, annot=True, fmt='g', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Generate a classification report
print(classification_report(true_classes, predicted_classes, target_names=class_labels))

# Save the model
model.save('/content/drive/MyDrive/DermatoAI/Models/DenseNet201_1.h5')
# Out:
# Found 8400 images belonging to 8 classes.
# Found 3600 images belonging to 8 classes.
# Class Indices: {'actinic_keratosis': 0, 'basal_cell_carcinoma': 1, 'dermatofibroma': 2, 'melanoma': 3, 'nevus': 4, 'pigmented_benign_keratosis': 5, 'squamous_cell_carcinoma': 6, 'vascular_lesion': 7}
# Index to Class: {0: 'actinic_keratosis', 1: 'basal_cell_carcinoma', 2: 'dermatofibroma', 3: 'melanoma', 4: 'nevus', 5: 'pigmented_benign_keratosis', 6: 'squamous_cell_carcinoma', 7: 'vascular_lesion'}
# Model: "model_14"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_15 (InputLayer)       [(None, 450, 600, 3)]        0         []
#
#  zero_padding2d_24 (ZeroPad  (None, 456, 606, 3)          0         ['input_15[0][0]']
#  ding2D)
#
#  conv1/conv (Conv2D)         (None, 225, 300, 64)         9408      ['zero_padding2d_24[0][0]']
#
#  conv1/bn (BatchNormalizati  (None, 225, 300, 64)         256       ['conv1/conv[0][0]']
#  on)
#
#  conv1/relu (Activation)     (None, 225, 300, 64)         0         ['conv1/bn[0][0]']
#
#  zero_padding2d_25 (ZeroPad  (None, 227, 302, 64)         0         ['conv1/relu[0][0]']
#  ding2D)
#
#  pool1 (MaxPooling2D)        (None, 113, 150, 64)         0         ['zero_padding2d_25[0][0]']
#
#  conv2_block1_0_bn (BatchNo  (None, 113, 150, 64)         256       ['pool1[0][0]']
#  rmalization)
#
#  conv2_block1_0_relu (Activ  (None, 113, 150, 64)         0         ['conv2_block1_0_bn[0][0]']
#  ation)
#
#  conv2_block1_1_conv (Conv2  (None, 113, 150, 128)        8192      ['conv2_block1_0_relu[0][0]']
#  D)
#
#  conv2_block1_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block1_1_conv[0][0]']
#  rmalization)
#
#  conv2_block1_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block1_1_bn[0][0]']
#  ation)
#
#  conv2_block1_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block1_1_relu[0][0]']
#  D)
#
#  conv2_block1_concat (Conca  (None, 113, 150, 96)         0         ['pool1[0][0]',
#  tenate)                                                             'conv2_block1_2_conv[0][0]']
#
#  conv2_block2_0_bn (BatchNo  (None, 113, 150, 96)         384       ['conv2_block1_concat[0][0]']
#  rmalization)
#
#  conv2_block2_0_relu (Activ  (None, 113, 150, 96)         0         ['conv2_block2_0_bn[0][0]']
#  ation)
#
#  conv2_block2_1_conv (Conv2  (None, 113, 150, 128)        12288     ['conv2_block2_0_relu[0][0]']
#  D)
#
#  conv2_block2_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block2_1_conv[0][0]']
#  rmalization)
#
#  conv2_block2_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block2_1_bn[0][0]']
#  ation)
#
#  conv2_block2_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block2_1_relu[0][0]']
#  D)
#
#  conv2_block2_concat (Conca  (None, 113, 150, 128)        0         ['conv2_block1_concat[0][0]',
#  tenate)                                                             'conv2_block2_2_conv[0][0]']
#
#  conv2_block3_0_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block2_concat[0][0]']
#  rmalization)
#
#  conv2_block3_0_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block3_0_bn[0][0]']
#  ation)
#
#  conv2_block3_1_conv (Conv2  (None, 113, 150, 128)        16384     ['conv2_block3_0_relu[0][0]']
#  D)
#
#  conv2_block3_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block3_1_conv[0][0]']
#  rmalization)
#
#  conv2_block3_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block3_1_bn[0][0]']
#  ation)
#
#  conv2_block3_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block3_1_relu[0][0]']
#  D)
#
#  conv2_block3_concat (Conca  (None, 113, 150, 160)        0         ['conv2_block2_concat[0][0]',
#  tenate)                                                             'conv2_block3_2_conv[0][0]']
#
#  conv2_block4_0_bn (BatchNo  (None, 113, 150, 160)        640       ['conv2_block3_concat[0][0]']
#  rmalization)
#
#  conv2_block4_0_relu (Activ  (None, 113, 150, 160)        0         ['conv2_block4_0_bn[0][0]']
#  ation)
#
#  conv2_block4_1_conv (Conv2  (None, 113, 150, 128)        20480     ['conv2_block4_0_relu[0][0]']
#  D)
#
#  conv2_block4_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block4_1_conv[0][0]']
#  rmalization)
#
#  conv2_block4_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block4_1_bn[0][0]']
#  ation)
#
#  conv2_block4_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block4_1_relu[0][0]']
#  D)
#
#  conv2_block4_concat (Conca  (None, 113, 150, 192)        0         ['conv2_block3_concat[0][0]',
#  tenate)                                                             'conv2_block4_2_conv[0][0]']
#
#  conv2_block5_0_bn (BatchNo  (None, 113, 150, 192)        768       ['conv2_block4_concat[0][0]']
#  rmalization)
#
#  conv2_block5_0_relu (Activ  (None, 113, 150, 192)        0         ['conv2_block5_0_bn[0][0]']
#  ation)
#
#  conv2_block5_1_conv (Conv2  (None, 113, 150, 128)        24576     ['conv2_block5_0_relu[0][0]']
#  D)
#
#  conv2_block5_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block5_1_conv[0][0]']
#  rmalization)
#
#  conv2_block5_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block5_1_bn[0][0]']
#  ation)
#
#  conv2_block5_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block5_1_relu[0][0]']
#  D)
#
#  conv2_block5_concat (Conca  (None, 113, 150, 224)        0         ['conv2_block4_concat[0][0]',
#  tenate)                                                             'conv2_block5_2_conv[0][0]']
#
#  conv2_block6_0_bn (BatchNo  (None, 113, 150, 224)        896       ['conv2_block5_concat[0][0]']
#  rmalization)
#
#  conv2_block6_0_relu (Activ  (None, 113, 150, 224)        0         ['conv2_block6_0_bn[0][0]']
#  ation)
#
#  conv2_block6_1_conv (Conv2  (None, 113, 150, 128)        28672     ['conv2_block6_0_relu[0][0]']
#  D)
#
#  conv2_block6_1_bn (BatchNo  (None, 113, 150, 128)        512       ['conv2_block6_1_conv[0][0]']
#  rmalization)
#
#  conv2_block6_1_relu (Activ  (None, 113, 150, 128)        0         ['conv2_block6_1_bn[0][0]']
#  ation)
#
#  conv2_block6_2_conv (Conv2  (None, 113, 150, 32)         36864     ['conv2_block6_1_relu[0][0]']
#  D)
#
#  conv2_block6_concat (Conca  (None, 113, 150, 256)        0         ['conv2_block5_concat[0][0]',
#  tenate)                                                             'conv2_block6_2_conv[0][0]']
#
#  pool2_bn (BatchNormalizati  (None, 113, 150, 256)        1024      ['conv2_block6_concat[0][0]']
#  on)
#
#  pool2_relu (Activation)     (None, 113, 150, 256)        0         ['pool2_bn[0][0]']
#
#  pool2_conv (Conv2D)         (None, 113, 150, 128)        32768     ['pool2_relu[0][0]']
#
#  pool2_pool (AveragePooling  (None, 56, 75, 128)          0         ['pool2_conv[0][0]']
#  2D)
#
#  conv3_block1_0_bn (BatchNo  (None, 56, 75, 128)          512       ['pool2_pool[0][0]']
#  rmalization)
#
#  conv3_block1_0_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block1_0_bn[0][0]']
#  ation)
#
#  conv3_block1_1_conv (Conv2  (None, 56, 75, 128)          16384     ['conv3_block1_0_relu[0][0]']
#  D)
#
#  conv3_block1_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block1_1_conv[0][0]']
#  rmalization)
#
#  conv3_block1_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block1_1_bn[0][0]']
#  ation)
#
#  conv3_block1_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block1_1_relu[0][0]']
#  D)
#
#  conv3_block1_concat (Conca  (None, 56, 75, 160)          0         ['pool2_pool[0][0]',
#  tenate)                                                             'conv3_block1_2_conv[0][0]']
#
#  conv3_block2_0_bn (BatchNo  (None, 56, 75, 160)          640       ['conv3_block1_concat[0][0]']
#  rmalization)
#
#  conv3_block2_0_relu (Activ  (None, 56, 75, 160)          0         ['conv3_block2_0_bn[0][0]']
#  ation)
#
#  conv3_block2_1_conv (Conv2  (None, 56, 75, 128)          20480     ['conv3_block2_0_relu[0][0]']
#  D)
#
#  conv3_block2_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block2_1_conv[0][0]']
#  rmalization)
#
#  conv3_block2_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block2_1_bn[0][0]']
#  ation)
#
#  conv3_block2_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block2_1_relu[0][0]']
#  D)
#
#  conv3_block2_concat (Conca  (None, 56, 75, 192)          0         ['conv3_block1_concat[0][0]',
#  tenate)                                                             'conv3_block2_2_conv[0][0]']
#
#  conv3_block3_0_bn (BatchNo  (None, 56, 75, 192)          768       ['conv3_block2_concat[0][0]']
#  rmalization)
#
#  conv3_block3_0_relu (Activ  (None, 56, 75, 192)          0         ['conv3_block3_0_bn[0][0]']
#  ation)
#
#  conv3_block3_1_conv (Conv2  (None, 56, 75, 128)          24576     ['conv3_block3_0_relu[0][0]']
#  D)
#
#  conv3_block3_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block3_1_conv[0][0]']
#  rmalization)
#
#  conv3_block3_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block3_1_bn[0][0]']
#  ation)
#
#  conv3_block3_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block3_1_relu[0][0]']
#  D)
#
#  conv3_block3_concat (Conca  (None, 56, 75, 224)          0         ['conv3_block2_concat[0][0]',
#  tenate)                                                             'conv3_block3_2_conv[0][0]']
#
#  conv3_block4_0_bn (BatchNo  (None, 56, 75, 224)          896       ['conv3_block3_concat[0][0]']
#  rmalization)
#
#  conv3_block4_0_relu (Activ  (None, 56, 75, 224)          0         ['conv3_block4_0_bn[0][0]']
#  ation)
#
#  conv3_block4_1_conv (Conv2  (None, 56, 75, 128)          28672     ['conv3_block4_0_relu[0][0]']
#  D)
#
#  conv3_block4_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block4_1_conv[0][0]']
#  rmalization)
#
#  conv3_block4_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block4_1_bn[0][0]']
#  ation)
#
#  conv3_block4_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block4_1_relu[0][0]']
#  D)
#
#  conv3_block4_concat (Conca  (None, 56, 75, 256)          0         ['conv3_block3_concat[0][0]',
#  tenate)                                                             'conv3_block4_2_conv[0][0]']
#
#  conv3_block5_0_bn (BatchNo  (None, 56, 75, 256)          1024      ['conv3_block4_concat[0][0]']
#  rmalization)
#
#  conv3_block5_0_relu (Activ  (None, 56, 75, 256)          0         ['conv3_block5_0_bn[0][0]']
#  ation)
#
#  conv3_block5_1_conv (Conv2  (None, 56, 75, 128)          32768     ['conv3_block5_0_relu[0][0]']
#  D)
#
#  conv3_block5_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block5_1_conv[0][0]']
#  rmalization)
#
#  conv3_block5_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block5_1_bn[0][0]']
#  ation)
#
#  conv3_block5_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block5_1_relu[0][0]']
#  D)
#
#  conv3_block5_concat (Conca  (None, 56, 75, 288)          0         ['conv3_block4_concat[0][0]',
#  tenate)                                                             'conv3_block5_2_conv[0][0]']
#
#  conv3_block6_0_bn (BatchNo  (None, 56, 75, 288)          1152      ['conv3_block5_concat[0][0]']
#  rmalization)
#
#  conv3_block6_0_relu (Activ  (None, 56, 75, 288)          0         ['conv3_block6_0_bn[0][0]']
#  ation)
#
#  conv3_block6_1_conv (Conv2  (None, 56, 75, 128)          36864     ['conv3_block6_0_relu[0][0]']
#  D)
#
#  conv3_block6_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block6_1_conv[0][0]']
#  rmalization)
#
#  conv3_block6_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block6_1_bn[0][0]']
#  ation)
#
#  conv3_block6_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block6_1_relu[0][0]']
#  D)
#
#  conv3_block6_concat (Conca  (None, 56, 75, 320)          0         ['conv3_block5_concat[0][0]',
#  tenate)                                                             'conv3_block6_2_conv[0][0]']
#
#  conv3_block7_0_bn (BatchNo  (None, 56, 75, 320)          1280      ['conv3_block6_concat[0][0]']
#  rmalization)
#
#  conv3_block7_0_relu (Activ  (None, 56, 75, 320)          0         ['conv3_block7_0_bn[0][0]']
#  ation)
#
#  conv3_block7_1_conv (Conv2  (None, 56, 75, 128)          40960     ['conv3_block7_0_relu[0][0]']
#  D)
#
#  conv3_block7_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block7_1_conv[0][0]']
#  rmalization)
#
#  conv3_block7_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block7_1_bn[0][0]']
#  ation)
#
#  conv3_block7_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block7_1_relu[0][0]']
#  D)
#
#  conv3_block7_concat (Conca  (None, 56, 75, 352)          0         ['conv3_block6_concat[0][0]',
#  tenate)                                                             'conv3_block7_2_conv[0][0]']
#
#  conv3_block8_0_bn (BatchNo  (None, 56, 75, 352)          1408      ['conv3_block7_concat[0][0]']
#  rmalization)
#
#  conv3_block8_0_relu (Activ  (None, 56, 75, 352)          0         ['conv3_block8_0_bn[0][0]']
#  ation)
#
#  conv3_block8_1_conv (Conv2  (None, 56, 75, 128)          45056     ['conv3_block8_0_relu[0][0]']
#  D)
#
#  conv3_block8_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block8_1_conv[0][0]']
#  rmalization)
#
#  conv3_block8_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block8_1_bn[0][0]']
#  ation)
#
#  conv3_block8_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block8_1_relu[0][0]']
#  D)
#
#  conv3_block8_concat (Conca  (None, 56, 75, 384)          0         ['conv3_block7_concat[0][0]',
#  tenate)                                                             'conv3_block8_2_conv[0][0]']
#
#  conv3_block9_0_bn (BatchNo  (None, 56, 75, 384)          1536      ['conv3_block8_concat[0][0]']
#  rmalization)
#
#  conv3_block9_0_relu (Activ  (None, 56, 75, 384)          0         ['conv3_block9_0_bn[0][0]']
#  ation)
#
#  conv3_block9_1_conv (Conv2  (None, 56, 75, 128)          49152     ['conv3_block9_0_relu[0][0]']
#  D)
#
#  conv3_block9_1_bn (BatchNo  (None, 56, 75, 128)          512       ['conv3_block9_1_conv[0][0]']
#  rmalization)
#
#  conv3_block9_1_relu (Activ  (None, 56, 75, 128)          0         ['conv3_block9_1_bn[0][0]']
#  ation)
#
#  conv3_block9_2_conv (Conv2  (None, 56, 75, 32)           36864     ['conv3_block9_1_relu[0][0]']
#  D)
#
#  conv3_block9_concat (Conca  (None, 56, 75, 416)          0         ['conv3_block8_concat[0][0]',
#  tenate)                                                             'conv3_block9_2_conv[0][0]']
#
#  conv3_block10_0_bn (BatchN  (None, 56, 75, 416)          1664      ['conv3_block9_concat[0][0]']
#  ormalization)
#
#  conv3_block10_0_relu (Acti  (None, 56, 75, 416)          0         ['conv3_block10_0_bn[0][0]']
#  vation)
#
#  conv3_block10_1_conv (Conv  (None, 56, 75, 128)          53248     ['conv3_block10_0_relu[0][0]']
#  2D)
#
#  conv3_block10_1_bn (BatchN  (None, 56, 75, 128)          512       ['conv3_block10_1_conv[0][0]']
#  ormalization)
#
#  conv3_block10_1_relu (Acti  (None, 56, 75, 128)          0         ['conv3_block10_1_bn[0][0]']
#  vation)
#
#  conv3_block10_2_conv (Conv  (None, 56, 75, 32)           36864     ['conv3_block10_1_relu[0][0]']
#  2D)
#
#  conv3_block10_concat (Conc  (None, 56, 75, 448)          0         ['conv3_block9_concat[0][0]',
#  atenate)                                                            'conv3_block10_2_conv[0][0]']
#
#  conv3_block11_0_bn (BatchN  (None, 56, 75, 448)          1792      ['conv3_block10_concat[0][0]']
#  ormalization)
#
#  conv3_block11_0_relu (Acti  (None, 56, 75, 448)          0         ['conv3_block11_0_bn[0][0]']
#  vation)
#
#  conv3_block11_1_conv (Conv  (None, 56, 75, 128)          57344     ['conv3_block11_0_relu[0][0]']
#  2D)
#
#  conv3_block11_1_bn (BatchN  (None, 56, 75, 128)          512       ['conv3_block11_1_conv[0][0]']
#  ormalization)
#
#  conv3_block11_1_relu (Acti  (None, 56, 75, 128)          0         ['conv3_block11_1_bn[0][0]']
#  vation)
#
#  conv3_block11_2_conv (Conv  (None, 56, 75, 32)           36864     ['conv3_block11_1_relu[0][0]']
#  2D)
#
#  conv3_block11_concat (Conc  (None, 56, 75, 480)          0         ['conv3_block10_concat[0][0]',
#  atenate)                                                            'conv3_block11_2_conv[0][0]']
#
#  conv3_block12_0_bn (BatchN  (None, 56, 75, 480)          1920      ['conv3_block11_concat[0][0]']
#  ormalization)
#
#  conv3_block12_0_relu (Acti  (None, 56, 75, 480)          0         ['conv3_block12_0_bn[0][0]']
#  vation)
#
#  conv3_block12_1_conv (Conv  (None, 56, 75, 128)          61440     ['conv3_block12_0_relu[0][0]']
#  2D)
#
#  conv3_block12_1_bn (BatchN  (None, 56, 75, 128)          512       ['conv3_block12_1_conv[0][0]']
#  ormalization)
#
#  conv3_block12_1_relu (Acti  (None, 56, 75, 128)          0         ['conv3_block12_1_bn[0][0]']
#  vation)
#
#  conv3_block12_2_conv (Conv  (None, 56, 75, 32)           36864     ['conv3_block12_1_relu[0][0]']
#  2D)
#
#  conv3_block12_concat (Conc  (None, 56, 75, 512)          0         ['conv3_block11_concat[0][0]',
#  atenate)                                                            'conv3_block12_2_conv[0][0]']
#
#  pool3_bn (BatchNormalizati  (None, 56, 75, 512)          2048      ['conv3_block12_concat[0][0]']
#  on)
#
#  pool3_relu (Activation)     (None, 56, 75, 512)          0         ['pool3_bn[0][0]']
#
#  pool3_conv (Conv2D)         (None, 56, 75, 256)          131072    ['pool3_relu[0][0]']
#
#  pool3_pool (AveragePooling  (None, 28, 37, 256)          0         ['pool3_conv[0][0]']
#  2D)
#
#  conv4_block1_0_bn (BatchNo  (None, 28, 37, 256)          1024      ['pool3_pool[0][0]']
#  rmalization)
#
#  conv4_block1_0_relu (Activ  (None, 28, 37, 256)          0         ['conv4_block1_0_bn[0][0]']
#  ation)
#
#  conv4_block1_1_conv (Conv2  (None, 28, 37, 128)          32768     ['conv4_block1_0_relu[0][0]']
#  D)
#
#  conv4_block1_1_bn (BatchNo  (None, 28, 37, 128)          512       ['conv4_block1_1_conv[0][0]']
#  rmalization)
#
#  conv4_block1_1_relu (Activ  (None, 28, 37, 128)          0         ['conv4_block1_1_bn[0][0]']
#  ation)
#
#  conv4_block1_2_conv (Conv2  (None, 28, 37, 32)           36864     ['conv4_block1_1_relu[0][0]']
#  D)
#
#  conv4_block1_concat (Conca  (None, 28, 37, 288)          0         ['pool3_pool[0][0]',
#  tenate)                                                             'conv4_block1_2_conv[0][0]']
#
#  conv4_block2_0_bn (BatchNo  (None, 28, 37, 288)          1152      ['conv4_block1_concat[0][0]']
#  rmalization)
#
#  conv4_block2_0_relu (Activ  (None, 28, 37, 288)          0         ['conv4_block2_0_bn[0][0]']
#  ation)
#
#  conv4_block2_1_conv (Conv2  (None, 28, 37, 128)          36864     ['conv4_block2_0_relu[0][0]']
#  D)
#
#  conv4_block2_1_bn (BatchNo  (None, 28, 37, 128)          512       ['conv4_block2_1_conv[0][0]']
#  rmalization)
#
#  conv4_block2_1_relu (Activ  (None, 28, 37, 128)          0         ['conv4_block2_1_bn[0][0]']
#  ation)
#
#  conv4_block2_2_conv (Conv2  (None, 28, 37, 32)           36864     ['conv4_block2_1_relu[0][0]']
#  D)
#
#  conv4_block2_concat (Conca  (None, 28, 37, 320)          0         ['conv4_block1_concat[0][0]',
#  tenate)                                                             'conv4_block2_2_conv[0][0]']
#
#  conv4_block3_0_bn (BatchNo  (None, 28, 37, 320)          1280      ['conv4_block2_concat[0][0]']
#  rmalization)
#
#  conv4_block3_0_relu (Activ  (None, 28, 37, 320)          0         ['conv4_block3_0_bn[0][0]']
#  ation)
#
#  conv4_block3_1_conv (Conv2  (None, 28, 37, 128)          40960     ['conv4_block3_0_relu[0][0]']
#  D)
#
#  conv4_block3_1_bn (BatchNo  (None, 28, 37, 128)          512       ['conv4_block3_1_conv[0][0]']
#  rmalization)
#
#  conv4_block3_1_relu (Activ  (None, 28, 37, 128)          0         ['conv4_block3_1_bn[0][0]']
#  ation)
#
#  conv4_block3_2_conv (Conv2  (None, 28, 37, 32)           36864     ['conv4_block3_1_relu[0][0]']
#  D)
#
#  conv4_block3_concat (Conca  (None, 28, 37, 352)          0         ['conv4_block2_concat[0][0]',
# ...
#
#  conv5_block30_0_relu (Acti  (None, 14, 18, 1824)         0         ['conv5_block30_0_bn[0][0]']
#  vation)
#
#  conv5_block30_1_conv (Conv  (None, 14, 18, 128)          233472    ['conv5_block30_0_relu[0][0]']
#  2D)
#
#  conv5_block30_1_bn (BatchN  (None, 14, 18, 128)          512       ['conv5_block30_1_conv[0][0]']
#  ormalization)
#
#  conv5_block30_1_relu (Acti  (None, 14, 18, 128)          0         ['conv5_block30_1_bn[0][0]']
#  vation)
#
#  conv5_block30_2_conv (Conv  (None, 14, 18, 32)           36864     ['conv5_block30_1_relu[0][0]']
#  2D)
#
#  conv5_block30_concat (Conc  (None, 14, 18, 1856)         0         ['conv5_block29_concat[0][0]',
#  atenate)                                                            'conv5_block30_2_conv[0][0]']
#
#  conv5_block31_0_bn (BatchN  (None, 14, 18, 1856)         7424      ['conv5_block30_concat[0][0]']
#  ormalization)
#
#  conv5_block31_0_relu (Acti  (None, 14, 18, 1856)         0         ['conv5_block31_0_bn[0][0]']
#  vation)
#
#  conv5_block31_1_conv (Conv  (None, 14, 18, 128)          237568    ['conv5_block31_0_relu[0][0]']
#  2D)
#
#  conv5_block31_1_bn (BatchN  (None, 14, 18, 128)          512       ['conv5_block31_1_conv[0][0]']
#  ormalization)
#
#  conv5_block31_1_relu (Acti  (None, 14, 18, 128)          0         ['conv5_block31_1_bn[0][0]']
#  vation)
#
#  conv5_block31_2_conv (Conv  (None, 14, 18, 32)           36864     ['conv5_block31_1_relu[0][0]']
#  2D)
#
#  conv5_block31_concat (Conc  (None, 14, 18, 1888)         0         ['conv5_block30_concat[0][0]',
#  atenate)                                                            'conv5_block31_2_conv[0][0]']
#
#  conv5_block32_0_bn (BatchN  (None, 14, 18, 1888)         7552      ['conv5_block31_concat[0][0]']
#  ormalization)
#
#  conv5_block32_0_relu (Acti  (None, 14, 18, 1888)         0         ['conv5_block32_0_bn[0][0]']
#  vation)
#
#  conv5_block32_1_conv (Conv  (None, 14, 18, 128)          241664    ['conv5_block32_0_relu[0][0]']
#  2D)
#
#  conv5_block32_1_bn (BatchN  (None, 14, 18, 128)          512       ['conv5_block32_1_conv[0][0]']
#  ormalization)
#
#  conv5_block32_1_relu (Acti  (None, 14, 18, 128)          0         ['conv5_block32_1_bn[0][0]']
#  vation)
#
#  conv5_block32_2_conv (Conv  (None, 14, 18, 32)           36864     ['conv5_block32_1_relu[0][0]']
#  2D)
#
#  conv5_block32_concat (Conc  (None, 14, 18, 1920)         0         ['conv5_block31_concat[0][0]',
#  atenate)                                                            'conv5_block32_2_conv[0][0]']
#
#  bn (BatchNormalization)     (None, 14, 18, 1920)         7680      ['conv5_block32_concat[0][0]']
#
#  relu (Activation)           (None, 14, 18, 1920)         0         ['bn[0][0]']
#
#  global_average_pooling2d_1  (None, 1920)                 0         ['relu[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  dense_47 (Dense)            (None, 512)                  983552    ['global_average_pooling2d_14[
#                                                                     0][0]']
#
#  batch_normalization_36 (Ba  (None, 512)                  2048      ['dense_47[0][0]']
#  tchNormalization)
#
#  activation_26 (Activation)  (None, 512)                  0         ['batch_normalization_36[0][0]
#                                                                     ']
#
#  dropout_31 (Dropout)        (None, 512)                  0         ['activation_26[0][0]']
#
#  dense_48 (Dense)            (None, 256)                  131328    ['dropout_31[0][0]']
#
#  batch_normalization_37 (Ba  (None, 256)                  1024      ['dense_48[0][0]']
#  tchNormalization)
#
#  activation_27 (Activation)  (None, 256)                  0         ['batch_normalization_37[0][0]
#                                                                     ']
#
#  dropout_32 (Dropout)        (None, 256)                  0         ['activation_27[0][0]']
#
#  dense_49 (Dense)            (None, 8)                    2056      ['dropout_32[0][0]']
#
# ==================================================================================================
# Total params: 19441992 (74.17 MB)
# Trainable params: 2530376 (9.65 MB)
# Non-trainable params: 16911616 (64.51 MB)
# __________________________________________________________________________________________________
# Epoch 1/20
# 525/525 [==============================] - 100s 161ms/step - loss: 1.6647 - accuracy: 0.4415 - precision_30: 0.5650 - recall_30: 0.3020 - f1_score: 0.3936 - val_loss: 1.1076 - val_accuracy: 0.6144 - val_precision_30: 0.7258 - val_recall_30: 0.4786 - val_f1_score: 0.5768 - lr: 3.0000e-04
# Epoch 2/20
# 525/525 [==============================] - 83s 157ms/step - loss: 1.0455 - accuracy: 0.6301 - precision_30: 0.7234 - recall_30: 0.5230 - f1_score: 0.6071 - val_loss: 1.0533 - val_accuracy: 0.6475 - val_precision_30: 0.7293 - val_recall_30: 0.5664 - val_f1_score: 0.6376 - lr: 3.0000e-04
# Epoch 3/20
# 525/525 [==============================] - 82s 156ms/step - loss: 0.7993 - accuracy: 0.7173 - precision_30: 0.7878 - recall_30: 0.6401 - f1_score: 0.7063 - val_loss: 0.8382 - val_accuracy: 0.7117 - val_precision_30: 0.7844 - val_recall_30: 0.6500 - val_f1_score: 0.7109 - lr: 3.0000e-04
# Epoch 4/20
# 525/525 [==============================] - 83s 159ms/step - loss: 0.6246 - accuracy: 0.7750 - precision_30: 0.8284 - recall_30: 0.7138 - f1_score: 0.7668 - val_loss: 0.8894 - val_accuracy: 0.7000 - val_precision_30: 0.7614 - val_recall_30: 0.6453 - val_f1_score: 0.6985 - lr: 3.0000e-04
# Epoch 5/20
# 525/525 [==============================] - 80s 153ms/step - loss: 0.4877 - accuracy: 0.8294 - precision_30: 0.8693 - recall_30: 0.7839 - f1_score: 0.8244 - val_loss: 1.2173 - val_accuracy: 0.6400 - val_precision_30: 0.6852 - val_recall_30: 0.5967 - val_f1_score: 0.6379 - lr: 3.0000e-04
# Epoch 6/20
# 525/525 [==============================] - 81s 153ms/step - loss: 0.4190 - accuracy: 0.8570 - precision_30: 0.8894 - recall_30: 0.8207 - f1_score: 0.8537 - val_loss: 0.7108 - val_accuracy: 0.7669 - val_precision_30: 0.8079 - val_recall_30: 0.7325 - val_f1_score: 0.7684 - lr: 3.0000e-04
# Epoch 7/20
# 525/525 [==============================] - 82s 156ms/step - loss: 0.3359 - accuracy: 0.8821 - precision_30: 0.9090 - recall_30: 0.8570 - f1_score: 0.8822 - val_loss: 0.7751 - val_accuracy: 0.7525 - val_precision_30: 0.7898 - val_recall_30: 0.7244 - val_f1_score: 0.7557 - lr: 3.0000e-04
# Epoch 8/20
# 525/525 [==============================] - 82s 155ms/step - loss: 0.2837 - accuracy: 0.9000 - precision_30: 0.9239 - recall_30: 0.8782 - f1_score: 0.9005 - val_loss: 0.8891 - val_accuracy: 0.7308 - val_precision_30: 0.7650 - val_recall_30: 0.7061 - val_f1_score: 0.7344 - lr: 3.0000e-04
# Epoch 9/20
# 525/525 [==============================] - ETA: 0s - loss: 0.2299 - accuracy: 0.9218 - precision_30: 0.9370 - recall_30: 0.9069 - f1_score: 0.9217
# Epoch 9: ReduceLROnPlateau reducing learning rate to 3.000000142492354e-05.
# 525/525 [==============================] - 84s 160ms/step - loss: 0.2299 - accuracy: 0.9218 - precision_30: 0.9370 - recall_30: 0.9069 - f1_score: 0.9217 - val_loss: 0.9163 - val_accuracy: 0.7322 - val_precision_30: 0.7603 - val_recall_30: 0.7111 - val_f1_score: 0.7349 - lr: 3.0000e-04
# Epoch 10/20
# 525/525 [==============================] - 82s 156ms/step - loss: 0.1425 - accuracy: 0.9574 - precision_30: 0.9663 - recall_30: 0.9480 - f1_score: 0.9570 - val_loss: 0.6901 - val_accuracy: 0.7914 - val_precision_30: 0.8166 - val_recall_30: 0.7717 - val_f1_score: 0.7935 - lr: 3.0000e-05
# Epoch 11/20
# 525/525 [==============================] - 82s 157ms/step - loss: 0.1138 - accuracy: 0.9682 - precision_30: 0.9753 - recall_30: 0.9598 - f1_score: 0.9675 - val_loss: 0.7034 - val_accuracy: 0.7847 - val_precision_30: 0.8119 - val_recall_30: 0.7628 - val_f1_score: 0.7866 - lr: 3.0000e-05
# Epoch 12/20
# 525/525 [==============================] - 82s 156ms/step - loss: 0.0908 - accuracy: 0.9765 - precision_30: 0.9817 - recall_30: 0.9699 - f1_score: 0.9757 - val_loss: 0.6564 - val_accuracy: 0.8000 - val_precision_30: 0.8230 - val_recall_30: 0.7825 - val_f1_score: 0.8022 - lr: 3.0000e-05
# Epoch 13/20
# 525/525 [==============================] - 80s 153ms/step - loss: 0.0856 - accuracy: 0.9770 - precision_30: 0.9810 - recall_30: 0.9714 - f1_score: 0.9762 - val_loss: 0.7001 - val_accuracy: 0.7917 - val_precision_30: 0.8134 - val_recall_30: 0.7711 - val_f1_score: 0.7917 - lr: 3.0000e-05
# Epoch 14/20
# 525/525 [==============================] - 81s 154ms/step - loss: 0.0829 - accuracy: 0.9786 - precision_30: 0.9827 - recall_30: 0.9729 - f1_score: 0.9777 - val_loss: 0.6929 - val_accuracy: 0.7989 - val_precision_30: 0.8147 - val_recall_30: 0.7806 - val_f1_score: 0.7973 - lr: 3.0000e-05
# Epoch 15/20
# 525/525 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9823 - precision_30: 0.9855 - recall_30: 0.9788 - f1_score: 0.9821
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.000000106112566e-06.
# 525/525 [==============================] - 81s 153ms/step - loss: 0.0706 - accuracy: 0.9823 - precision_30: 0.9855 - recall_30: 0.9788 - f1_score: 0.9821 - val_loss: 0.6840 - val_accuracy: 0.8014 - val_precision_30: 0.8212 - val_recall_30: 0.7858 - val_f1_score: 0.8031 - lr: 3.0000e-05
# Epoch 16/20
# 525/525 [==============================] - ETA: 0s - loss: 0.0690 - accuracy: 0.9835 - precision_30: 0.9862 - recall_30: 0.9799 - f1_score: 0.9830Restoring model weights from the end of the best epoch: 12.
# 525/525 [==============================] - 82s 156ms/step - loss: 0.0690 - accuracy: 0.9835 - precision_30: 0.9862 - recall_30: 0.9799 - f1_score: 0.9830 - val_loss: 0.6684 - val_accuracy: 0.8056 - val_precision_30: 0.8256 - val_recall_30: 0.7889 - val_f1_score: 0.8068 - lr: 3.0000e-06
# Epoch 16: early stopping
# 225/225 [==============================] - 27s 106ms/step
#                             precision    recall  f1-score   support
#
#          actinic_keratosis       0.93      0.86      0.89       450
#       basal_cell_carcinoma       0.81      0.82      0.81       450
#             dermatofibroma       0.92      0.73      0.81       450
#                   melanoma       0.65      0.71      0.68       450
#                      nevus       0.75      0.84      0.79       450
# pigmented_benign_keratosis       0.62      0.81      0.70       450
#    squamous_cell_carcinoma       0.86      0.73      0.79       450
#            vascular_lesion       0.99      0.91      0.95       450
#
#                   accuracy                           0.80      3600
#                  macro avg       0.82      0.80      0.80      3600
#               weighted avg       0.82      0.80      0.80      3600
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
